# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('human_development.csv')
df1.head(10)
# Out:
#    HDI Rank        Country  Human Development Index (HDI)  \
# 0       1.0         Norway                          0.944
# 1       2.0      Australia                          0.935
# 2       3.0    Switzerland                          0.930
# 3       4.0        Denmark                          0.923
# 4       5.0    Netherlands                          0.922
# 5       6.0        Germany                          0.916
# 6       6.0        Ireland                          0.916
# 7       8.0  United States                          0.915
# 8       9.0         Canada                          0.913
# 9       9.0    New Zealand                          0.913
#
#    Life Expectancy at Birth  Expected Years of Education  \
# 0                      81.6                         17.5
# 1                      82.4                         20.2
# 2                      83.0                         15.8
# 3                      80.2                         18.7
# ...

# %%
df1.shape
# Out:
# (195, 8)

# %%
# convertir object columns in float columns
df1['Gross National Income (GNI) per Capita'] = pd.to_numeric(df1['Gross National Income (GNI) per Capita'], errors='coerce')

# %%
df1.columns
# Out:
# Index(['HDI Rank', 'Country', 'Human Development Index (HDI)',
#        'Life Expectancy at Birth', 'Expected Years of Education',
#        'Mean Years of Education', 'Gross National Income (GNI) per Capita',
#        'GNI per Capita Rank Minus HDI Rank'],
#       dtype='object')

# %%
df2 = pd.read_csv('gender_development.csv')
df2.head(10)
# Out:
#    GDI Rank        Country Gender Development Index (GDI)  \
# 0       1.0         Norway                          0.996
# 1       2.0      Australia                          0.976
# 2       3.0    Switzerland                           0.95
# 3       4.0        Denmark                          0.977
# 4       5.0    Netherlands                          0.947
# 5       6.0        Germany                          0.963
# 6       6.0        Ireland                          0.973
# 7       8.0  United States                          0.995
# 8       9.0         Canada                          0.982
# 9       9.0    New Zealand                          0.961
#
#   Human Development Index (Female) Human Development Index (Male)  \
# 0                             0.94                          0.944
# 1                            0.922                          0.945
# 2                            0.898                          0.945
# ...

# %%
df2.shape
# Out:
# (195, 13)

# %%
# convertir object columns in float columns
df2['Human Development Index (Female)'] = pd.to_numeric(df2['Human Development Index (Female)'], errors='coerce')
df2['Human Development Index (Male)'] = pd.to_numeric(df2['Human Development Index (Male)'], errors='coerce')
df2['Life Expectancy at Birth (Female)'] = pd.to_numeric(df2['Life Expectancy at Birth (Female)'], errors='coerce')
df2['Life Expectancy at Birth (Male)'] = pd.to_numeric(df2['Life Expectancy at Birth (Male)'], errors='coerce')
df2['Expected Years of Education (Female)'] = pd.to_numeric(df2['Expected Years of Education (Female)'], errors='coerce')
df2['Expected Years of Education (Male)'] = pd.to_numeric(df2['Expected Years of Education (Male)'], errors='coerce')
df2['Mean Years of Education (Female)'] = pd.to_numeric(df2['Mean Years of Education (Female)'], errors='coerce')
df2['Mean Years of Education (Male)'] = pd.to_numeric(df2['Mean Years of Education (Male)'], errors='coerce')
df2['Estimated Gross National Income per Capita (Female)'] = pd.to_numeric(df2['Estimated Gross National Income per Capita (Female)'], errors='coerce')
df2['Estimated Gross National Income per Capita (Male)'] = pd.to_numeric(df2['Estimated Gross National Income per Capita (Male)'], errors='coerce')

# %%
df2['Gender Development Index (GDI)'] = pd.to_numeric(df2['Gender Development Index (GDI)'], errors='coerce')

# %%
df2.dtypes
# Out:
# GDI Rank                                               float64
# Country                                                 object
# Gender Development Index (GDI)                         float64
# Human Development Index (Female)                       float64
# Human Development Index (Male)                         float64
# Life Expectancy at Birth (Female)                      float64
# Life Expectancy at Birth (Male)                        float64
# Expected Years of Education (Female)                   float64
# Expected Years of Education (Male)                     float64
# Mean Years of Education (Female)                       float64
# Mean Years of Education (Male)                         float64
# Estimated Gross National Income per Capita (Female)    float64
# Estimated Gross National Income per Capita (Male)      float64
# dtype: object

# %%
df2.columns
# Out:
# Index(['GDI Rank', 'Country', 'Gender Development Index (GDI)',
#        'Human Development Index (Female)', 'Human Development Index (Male)',
#        'Life Expectancy at Birth (Female)', 'Life Expectancy at Birth (Male)',
#        'Expected Years of Education (Female)',
#        'Expected Years of Education (Male)',
#        'Mean Years of Education (Female)', 'Mean Years of Education (Male)',
#        'Estimated Gross National Income per Capita (Female)',
#        'Estimated Gross National Income per Capita (Male)'],
#       dtype='object')

# %%
df3 = pd.read_csv('inequality_adjusted.csv')
df3.head(10)
# Out:
#    IHDI Rank        Country  Human Development Index (HDI)  \
# 0        1.0         Norway                          0.944
# 1        2.0      Australia                          0.935
# 2        3.0    Switzerland                          0.930
# 3        4.0        Denmark                          0.923
# 4        5.0    Netherlands                          0.922
# 5        6.0        Germany                          0.916
# 6        6.0        Ireland                          0.916
# 7        8.0  United States                          0.915
# 8        9.0         Canada                          0.913
# 9        9.0    New Zealand                          0.913
#
#   Inequality-adjusted HDI (IHDI) IHDI Loss Percent IHDI Rank Difference  \
# 0                          0.893               5.4                    0
# 1                          0.858               8.2                   -2
# 2                          0.861               7.4                    0
# ...

# %%
# convertir object columns in float columns
df3['Coefficient of Human Inequality'] = pd.to_numeric(df3['Coefficient of Human Inequality'], errors='coerce')
df3['Inequality in Life Expectancy'] = pd.to_numeric(df3['Inequality in Life Expectancy'], errors='coerce')
df3['Inequality in Education'] = pd.to_numeric(df3['Inequality in Education'], errors='coerce')
df3['Inequality in Income'] = pd.to_numeric(df3['Inequality in Income'], errors='coerce')

# %%
df3.dtypes
# Out:
# IHDI Rank                                    float64
# Country                                       object
# Human Development Index (HDI)                float64
# Inequality-adjusted HDI (IHDI)                object
# IHDI Loss Percent                             object
# IHDI Rank Difference                          object
# Coefficient of Human Inequality              float64
# Inequality in Life Expectancy                float64
# Inequality-Adjusted Life Expectancy Index     object
# Inequality in Education                      float64
# Inequality-Adjusted Education Index           object
# Inequality in Income                         float64
# Inequality-Adjusted Income Index              object
# Income Inequality (Quintile Ratio)            object
# Income Inequality (Palma Rati)                object
# Income Inequality (Gini Coefficient)          object
# dtype: object

# %%
df3.shape
# Out:
# (195, 16)

# %%
df3.columns
# Out:
# Index(['IHDI Rank', 'Country', 'Human Development Index (HDI)',
#        'Inequality-adjusted HDI (IHDI)', 'IHDI Loss Percent',
#        'IHDI Rank Difference', 'Coefficient of Human Inequality',
#        'Inequality in Life Expectancy',
#        'Inequality-Adjusted Life Expectancy Index', 'Inequality in Education',
#        'Inequality-Adjusted Education Index', 'Inequality in Income',
#        'Inequality-Adjusted Income Index',
#        'Income Inequality (Quintile Ratio)', 'Income Inequality (Palma Rati)',
#        'Income Inequality (Gini Coefficient)'],
#       dtype='object')

# %%
# verifier que GDI Rank et Country pour df2 ont les memes valeurs que les colonnes HDI Rank et	Country pour df1 
df1['Country'].isin(df2['Country']).value_counts()
# Out:
# True    195
# Name: Country, dtype: int64

# %%
df1['HDI Rank'].isin(df2['GDI Rank']).value_counts()
# Out:
# True    195
# Name: HDI Rank, dtype: int64

# %%
# verifier que GDI Rank et Country pour df2 ont les memes valeurs que les colonnes IHDI Rank et Country pour df3
df2['Country'].isin(df3['Country']).value_counts()
# Out:
# True    195
# Name: Country, dtype: int64

# %%
df2['GDI Rank'].isin(df3['IHDI Rank']).value_counts()
# Out:
# True    195
# Name: GDI Rank, dtype: int64

# %%
# verifier que HDI Rank et Country pour df1 ont les memes valeurs que les colonnes IHDI Rank et Country pour df3
df1['Country'].isin(df3['Country']).value_counts()
# Out:
# True    195
# Name: Country, dtype: int64

# %%
df1['HDI Rank'].isin(df3['IHDI Rank']).value_counts()
# Out:
# True    195
# Name: HDI Rank, dtype: int64

# %% [markdown]
# Ayant les memes ranks et memes pays, nous allons selectionner les colonnes les plus utliles et ensuite former un seul dataset

# %%
# supprimer les colonnes inutiles dans df1
new_df1 = df1.drop(['GNI per Capita Rank Minus HDI Rank'],axis=1)

# %%
# supprimer les colonnes inutiles dans df2
new_df2 = df2.drop(columns=['GDI Rank', 'Country'], axis=1)

# %%
# supprimer les colonnes inutiles dans df3
new_df3 = df3.drop(['IHDI Rank', 'Country', 'Human Development Index (HDI)',
       'Inequality-adjusted HDI (IHDI)', 'IHDI Loss Percent',
       'IHDI Rank Difference',
       'Inequality-Adjusted Life Expectancy Index',
       'Inequality-Adjusted Education Index',
       'Inequality-Adjusted Income Index',
       'Income Inequality (Quintile Ratio)', 'Income Inequality (Palma Rati)', 
       'Income Inequality (Gini Coefficient)'], axis=1)

# %% [markdown]
# ASSEMBLER TOUS LES DATASETS

# %%
# Assembler (concat) tous les datasets en un seul dataset
horizontal_df = pd.concat([new_df1, new_df2, new_df3], axis=1)
horizontal_df
# Out:
#      HDI Rank                          Country  Human Development Index (HDI)  \
# 0         1.0                           Norway                          0.944
# 1         2.0                        Australia                          0.935
# 2         3.0                      Switzerland                          0.930
# 3         4.0                          Denmark                          0.923
# 4         5.0                      Netherlands                          0.922
# ..        ...                              ...                            ...
# 190       NaN          Europe and Central Asia                          0.748
# 191       NaN  Latin America and the Caribbean                          0.748
# 192       NaN                       South Asia                          0.607
# 193       NaN               Sub-Saharan Africa                          0.518
# 194       NaN                            World                          0.711
#
# ...

# %%
horizontal_df.dtypes
# Out:
# HDI Rank                                               float64
# Country                                                 object
# Human Development Index (HDI)                          float64
# Life Expectancy at Birth                               float64
# Expected Years of Education                            float64
# Mean Years of Education                                float64
# Gross National Income (GNI) per Capita                 float64
# Gender Development Index (GDI)                         float64
# Human Development Index (Female)                       float64
# Human Development Index (Male)                         float64
# Life Expectancy at Birth (Female)                      float64
# Life Expectancy at Birth (Male)                        float64
# Expected Years of Education (Female)                   float64
# Expected Years of Education (Male)                     float64
# Mean Years of Education (Female)                       float64
# ...

# %%
horizontal_df.isnull().sum()
# Out:
# HDI Rank                                                 7
# Country                                                  0
# Human Development Index (HDI)                            0
# Life Expectancy at Birth                                 0
# Expected Years of Education                              0
# Mean Years of Education                                  0
# Gross National Income (GNI) per Capita                 189
# Gender Development Index (GDI)                          27
# Human Development Index (Female)                        27
# Human Development Index (Male)                          27
# Life Expectancy at Birth (Female)                        5
# Life Expectancy at Birth (Male)                          5
# Expected Years of Education (Female)                    14
# Expected Years of Education (Male)                      14
# Mean Years of Education (Female)                        18
# Mean Years of Education (Male)                          18
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
# imputer les valeurs manquates 
horizontal_df['HDI Rank'].fillna(method='ffill', inplace=True)

# %%
horizontal_df.fillna(horizontal_df.median(numeric_only=True), inplace=True)

# %%
horizontal_df.head(5)
# Out:
#    HDI Rank      Country  Human Development Index (HDI)  \
# 0       1.0       Norway                          0.944
# 1       2.0    Australia                          0.935
# 2       3.0  Switzerland                          0.930
# 3       4.0      Denmark                          0.923
# 4       5.0  Netherlands                          0.922
#
#    Life Expectancy at Birth  Expected Years of Education  \
# 0                      81.6                         17.5
# 1                      82.4                         20.2
# 2                      83.0                         15.8
# 3                      80.2                         18.7
# 4                      81.6                         17.9
#
#    Mean Years of Education  Gross National Income (GNI) per Capita  \
# 0                     12.6                                   752.5
# 1                     13.0                                   752.5
# 2                     12.8                                   752.5
# ...

# %% [markdown]
# Identifier les outliers

# %%
# detecter les outliers par la methode des interquartile iqr
def detect_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    return data[(data[column] > upper_limit) | (data[column] < lower_limit)]

# %%
features = ['Human Development Index (HDI)',
       'Life Expectancy at Birth', 'Expected Years of Education',
       'Mean Years of Education', 'Gross National Income (GNI) per Capita',
       'Gender Development Index (GDI)', 'Human Development Index (Female)',
       'Human Development Index (Male)', 'Life Expectancy at Birth (Female)',
       'Life Expectancy at Birth (Male)',
       'Expected Years of Education (Female)',
       'Expected Years of Education (Male)',
       'Mean Years of Education (Female)', 'Mean Years of Education (Male)',
       'Estimated Gross National Income per Capita (Female)',
       'Estimated Gross National Income per Capita (Male)',
       'Coefficient of Human Inequality', 'Inequality in Life Expectancy',
       'Inequality in Education', 'Inequality in Income']

# %%
for feature in features:
    show_detect_outliers = detect_outliers(horizontal_df, features)
